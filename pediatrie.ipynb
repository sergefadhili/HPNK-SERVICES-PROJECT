# %%
import pandas as pd
import numpy as  sp
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as   plt

# %%
import os

# %%
df =pd.read_csv(r"D:\Pharma analyse\pediatrieCon.csv")

# %%
df
# Out:
#                                   cEVT_ID    cEVT_Date cCHP_VAL_Alpha  \
# 0    1445d354-842a-4e34-868b-870115d1ffe1  45096.63206            NaN
# 1    5d53b8de-e964-4077-8093-4af43e947179  45038.45898            NaN
# 2    be99614c-e73f-4eee-8915-81394435aa95  45030.50928            NaN
# 3    b19d4859-ff8a-4f98-8399-b61d6ffb75f1  44932.42413         CUSTOM
# 4    882ea33e-61b4-4688-80fd-0e8a0dea6757  45077.43109         CUSTOM
# ..                                    ...          ...            ...
# 114  737a0c45-e9ea-4a95-8ecd-99d1a5837c07  45227.45625            NaN
# 115  63f7ac1f-54f4-4b24-82c5-f66830a27128  45216.66250         CUSTOM
# 116  ef2bb93b-00d5-4f70-927f-bb4412d985cf  45275.43958            NaN
# 117  ef2bb93b-00d5-4f70-927f-bb4412d985cf  45275.43958         CUSTOM
# 118  75f4cec5-c3fc-4949-a140-264fa970b1a7  45166.52917            NaN
#
#      cCHP_VAL_Num                                      cCHP_VAL_Memo  \
# ...

# %%
df.columns
# Out:
# Index(['cEVT_ID', 'cEVT_Date', 'cCHP_VAL_Alpha', 'cCHP_VAL_Num',
#        'cCHP_VAL_Memo', 'cCHP_Code', 'NOM COMPLET', 'cPAT_Genre', 'DNN',
#        'ANNE', 'AGE', '<= 5ans'],
#       dtype='object')

# %%
df.head()
# Out:
#                                 cEVT_ID    cEVT_Date cCHP_VAL_Alpha  \
# 0  1445d354-842a-4e34-868b-870115d1ffe1  45096.63206            NaN
# 1  5d53b8de-e964-4077-8093-4af43e947179  45038.45898            NaN
# 2  be99614c-e73f-4eee-8915-81394435aa95  45030.50928            NaN
# 3  b19d4859-ff8a-4f98-8399-b61d6ffb75f1  44932.42413         CUSTOM
# 4  882ea33e-61b4-4688-80fd-0e8a0dea6757  45077.43109         CUSTOM
#
#    cCHP_VAL_Num                                      cCHP_VAL_Memo  \
# 0           NaN  1erF son frère en BSA\ntransfusion + 1x pathol...
# 1           NaN  5eme sur 5 accouche par césarienne pour micros...
# 2           NaN  Drépanocytaire connu  ,suivi à l’HPNK, sous hy...
# 3           1.0                          myocardiopathie acquise ?
# 4           1.0                                       cardiopathie
#
#          cCHP_Code                  NOM COMPLET cPAT_Genre         DNN  ANNE  \
# ...

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                                   cEVT_ID    cEVT_Date cCHP_VAL_Alpha  \
# 0    1445d354-842a-4e34-868b-870115d1ffe1  45096.63206            NaN
# 1    5d53b8de-e964-4077-8093-4af43e947179  45038.45898            NaN
# 2    be99614c-e73f-4eee-8915-81394435aa95  45030.50928            NaN
# 3    b19d4859-ff8a-4f98-8399-b61d6ffb75f1  44932.42413         CUSTOM
# 4    882ea33e-61b4-4688-80fd-0e8a0dea6757  45077.43109         CUSTOM
# ..                                    ...          ...            ...
# 114  737a0c45-e9ea-4a95-8ecd-99d1a5837c07  45227.45625            NaN
# 115  63f7ac1f-54f4-4b24-82c5-f66830a27128  45216.66250         CUSTOM
# 116  ef2bb93b-00d5-4f70-927f-bb4412d985cf  45275.43958            NaN
# 117  ef2bb93b-00d5-4f70-927f-bb4412d985cf  45275.43958         CUSTOM
# 118  75f4cec5-c3fc-4949-a140-264fa970b1a7  45166.52917            NaN
#
#      cCHP_VAL_Num                                      cCHP_VAL_Memo  \
# ...

# %%
df.dtypes
# Out:
# cEVT_ID            object
# cEVT_Date         float64
# cCHP_VAL_Alpha     object
# cCHP_VAL_Num      float64
# cCHP_VAL_Memo      object
# cCHP_Code          object
# NOM COMPLET        object
# cPAT_Genre         object
# DNN                object
# ANNE                int64
# AGE                 int64
# <= 5ans            object
# dtype: object

# %%
df.nunique()
# Out:
# cEVT_ID           106
# cEVT_Date         106
# cCHP_VAL_Alpha      1
# cCHP_VAL_Num        2
# cCHP_VAL_Memo     105
# cCHP_Code           8
# NOM COMPLET        87
# cPAT_Genre          2
# DNN                84
# ANNE               19
# AGE                19
# <= 5ans             2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cEVT_ID         119 non-null    object
#  1   cEVT_Date       119 non-null    float64
#  2   cCHP_VAL_Alpha  63 non-null     object
#  3   cCHP_VAL_Num    66 non-null     float64
#  4   cCHP_VAL_Memo   119 non-null    object
#  5   cCHP_Code       119 non-null    object
#  6   NOM COMPLET     119 non-null    object
#  7   cPAT_Genre      119 non-null    object
#  8   DNN             119 non-null    object
#  9   ANNE            119 non-null    int64
#  10  AGE             119 non-null    int64
#  11  <= 5ans         119 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 11.3+ KB

# %%
df.describe()
# Out:
#           cEVT_Date  cCHP_VAL_Num         ANNE         AGE
# count    119.000000     66.000000   119.000000  119.000000
# mean   45140.739801      0.954545  2017.428571    6.571429
# std       98.603453      0.209895     5.516649    5.516649
# min    44932.424130      0.000000  2005.000000    1.000000
# 25%    45074.511645      1.000000  2012.000000    2.000000
# 50%    45141.488320      1.000000  2020.000000    4.000000
# 75%    45225.473265      1.000000  2022.000000   12.000000
# max    45288.464580      1.000000  2023.000000   19.000000

# %%
df.count()
# Out:
# cEVT_ID           119
# cEVT_Date         119
# cCHP_VAL_Alpha     63
# cCHP_VAL_Num       66
# cCHP_VAL_Memo     119
# cCHP_Code         119
# NOM COMPLET       119
# cPAT_Genre        119
# DNN               119
# ANNE              119
# AGE               119
# <= 5ans           119
# dtype: int64

# %%
df["cCHP_VAL_Memo"].value_counts()
# Out:
# cardiopathie                                                                                                                                                                                                                                                                               6
# cardiopathie                                                                                                                                                                                                                                                                               4
# cardiopathie congénitale                                                                                                                                                                                                                                                                   3
# ...

# %%
df.nunique()
# Out:
# cEVT_ID           106
# cEVT_Date         106
# cCHP_VAL_Alpha      1
# cCHP_VAL_Num        2
# cCHP_VAL_Memo     105
# cCHP_Code           8
# NOM COMPLET        87
# cPAT_Genre          2
# DNN                84
# ANNE               19
# AGE                19
# <= 5ans             2
# dtype: int64
